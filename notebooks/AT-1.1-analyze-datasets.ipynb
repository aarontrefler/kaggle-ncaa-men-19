# %% [markdown]
# # Setup

# %%
import pdb
import sys

import numpy as np
import pandas as pd
import seaborn as sns

# %%
# %reload_ext autoreload
# %autoreload 2

src_path = "/Users/aarontrefler_temp2/Documents/My Documents/Kaggle/ncaa-men-19/src"
sys.path.insert(0, src_path)

import data.data_utils as data
import utils

pd.options.display.max_columns = 999

# %%
data_raw_dir = utils.project_path + 'data/raw/'
data_interim_dir = utils.project_path + 'data/interim/'
data_clean_dir = utils.project_path + 'data/clean/'

# %% [markdown]
# # Read and Display Modeling Datasets

# %% [markdown]
# ## Modeling Interim Dataset

# %%
df_interim_mdl = (pd.read_csv(data_interim_dir + 'model_dataset.csv'))
utils.display_df(df_interim_mdl, n=3, tail=True, title="Past Games")
# Out:
# Past Games:
#    Season TeamOne_Name     TeamTwo_Name  TeamOneID  TeamTwoID  Label  \
# 0    1985      Alabama          Arizona       1104       1112      1
# 1    1985      Alabama         NC State       1104       1301      0
# 2    1985      Alabama  VA Commonwealth       1104       1433      1
#
#    TeamOne_Seed  TeamTwo_Seed  TeamOne_Ast  TeamOne_Ast_opp  TeamOne_Blk  \
# 0             7            10          NaN              NaN          NaN
# 1             7             3          NaN              NaN          NaN
# 2             7             2          NaN              NaN          NaN
#
#    TeamOne_Blk_opp  TeamOne_DR  TeamOne_DR_opp  TeamOne_FGA  TeamOne_FGA3  \
# 0              NaN         NaN             NaN          NaN           NaN
# 1              NaN         NaN             NaN          NaN           NaN
# 2              NaN         NaN             NaN          NaN           NaN
#
#    TeamOne_FGA3_opp  TeamOne_FGA_opp  TeamOne_FGM  TeamOne_FGM3  \
# ...

# %% [markdown]
# ## Modeling Clean Dataset

# %%
df_clean_mdl = (pd.read_csv(data_clean_dir + 'model_dataset.csv'))
utils.display_df(df_clean_mdl, n=3, tail=True, title="Past Games")
# Out:
# Past Games:
#    Season  TeamOneID  TeamTwoID  Label  TeamOne_Seed  TeamTwo_Seed  \
# 0  1985.0     1104.0     1112.0    1.0           7.0          10.0
# 1  1985.0     1104.0     1301.0    0.0           7.0           3.0
# 2  1985.0     1104.0     1433.0    1.0           7.0           2.0
#
#    TeamOne_Ast  TeamOne_Ast_opp  TeamOne_Blk  TeamOne_Blk_opp  TeamOne_DR  \
# 0    14.774194        11.939394          4.0         3.135632        24.8
# 1    14.774194        11.939394          4.0         3.135632        24.8
# 2    14.774194        11.939394          4.0         3.135632        24.8
#
#    TeamOne_DR_opp  TeamOne_FGA  TeamOne_FGA3  TeamOne_FGA3_opp  \
# 0       21.863971    56.716578     18.741935         18.727273
# 1       21.863971    56.716578     18.741935         18.727273
# 2       21.863971    56.716578     18.741935         18.727273
#
#    TeamOne_FGA_opp  TeamOne_FGM  TeamOne_FGM3  TeamOne_FGM3_opp  \
# ...

# %% [markdown]
# ## Modeling Train and Validation Datasets with Predictions

# %%
# training dataset with predictions
df_train_pred = (pd.read_csv(data_clean_dir + 'predictions_train_dataset.csv'))
utils.display_df(df_train_pred, n=5, tail=True, title="Taining Set Past Games")

# validation dataset with predictions
df_valid_pred = (pd.read_csv(data_clean_dir + 'predictions_valid_dataset.csv'))
utils.display_df(df_valid_pred, n=5, tail=True, title="Validation Set Past Games")
# Out:
# Taining Set Past Games:
#        Pred  Label  Season  TeamOneID  TeamTwoID  TeamOne_Seed  TeamTwo_Seed  \
# 0  0.534415    1.0  1985.0     1104.0     1112.0           7.0          10.0
# 1  0.392983    0.0  1985.0     1104.0     1301.0           7.0           3.0
# 2  0.348132    1.0  1985.0     1104.0     1433.0           7.0           2.0
# 3  0.472668    1.0  1985.0     1116.0     1234.0           9.0           8.0
# 4  0.206320    0.0  1985.0     1116.0     1385.0           9.0           1.0
#
#    TeamOne_Ast  TeamOne_Ast_opp  TeamOne_Blk  TeamOne_Blk_opp  TeamOne_DR  \
# 0    14.774194        11.939394          4.0         3.135632        24.8
# 1    14.774194        11.939394          4.0         3.135632        24.8
# 2    14.774194        11.939394          4.0         3.135632        24.8
# 3    14.774194        11.939394          4.0         3.135632        24.8
# 4    14.774194        11.939394          4.0         3.135632        24.8
#
# ...

# %% [markdown]
# # Read and Display Submission Dataset

# %% [markdown]
# ## Submission Interim Dataset

# %%
df_interim_sub = (pd.read_csv(data_interim_dir + 'submission_dataset.csv'))
utils.display_df(df_interim_sub, n=3, tail=True, title="2019 Potential Games")
# Out:
# 2019 Potential Games:
#    Season TeamOne_Name TeamTwo_Name  TeamOneID  TeamTwoID  TeamOne_Seed  \
# 0    2019  Abilene Chr   Arizona St       1101       1113            15
# 1    2019  Abilene Chr       Auburn       1101       1120            15
# 2    2019  Abilene Chr       Baylor       1101       1124            15
#
#    TeamTwo_Seed  TeamOne_Ast  TeamOne_Ast_opp  TeamOne_Blk  TeamOne_Blk_opp  \
# 0            11     14.62069        11.103448     2.551724         2.965517
# 1             5     14.62069        11.103448     2.551724         2.965517
# 2             9     14.62069        11.103448     2.551724         2.965517
#
#    TeamOne_DR  TeamOne_DR_opp  TeamOne_FGA  TeamOne_FGA3  TeamOne_FGA3_opp  \
# 0   22.896552       23.758621    55.241379     18.896552         17.103448
# 1   22.896552       23.758621    55.241379     18.896552         17.103448
# 2   22.896552       23.758621    55.241379     18.896552         17.103448
#
# ...

# %% [markdown]
# ## Submission Clean Dataset

# %%
df_clean_sub = (pd.read_csv(data_clean_dir + 'submission_dataset.csv'))
utils.display_df(df_clean_sub, n=3, tail=True, title="2019 Potential Games")
# Out:
# 2019 Potential Games:
#    Season  TeamOneID  TeamTwoID  TeamOne_Seed  TeamTwo_Seed  TeamOne_Ast  \
# 0  2019.0     1101.0     1113.0          15.0          11.0     14.62069
# 1  2019.0     1101.0     1120.0          15.0           5.0     14.62069
# 2  2019.0     1101.0     1124.0          15.0           9.0     14.62069
#
#    TeamOne_Ast_opp  TeamOne_Blk  TeamOne_Blk_opp  TeamOne_DR  TeamOne_DR_opp  \
# 0        11.103448     2.551724         2.965517   22.896552       23.758621
# 1        11.103448     2.551724         2.965517   22.896552       23.758621
# 2        11.103448     2.551724         2.965517   22.896552       23.758621
#
#    TeamOne_FGA  TeamOne_FGA3  TeamOne_FGA3_opp  TeamOne_FGA_opp  TeamOne_FGM  \
# 0    55.241379     18.896552         17.103448        51.137931    25.344828
# 1    55.241379     18.896552         17.103448        51.137931    25.344828
# 2    55.241379     18.896552         17.103448        51.137931    25.344828
#
# ...

# %% [markdown]
# ## Submission Clean Dataset with Predictions

# %%
# training dataset with predictions
df_sub_pred = (pd.read_csv(data_clean_dir + 'predictions_submission_dataset.csv'))
utils.display_df(df_sub_pred, n=10, tail=True, title="2019 Potential Games")
# Out:
# 2019 Potential Games:
#        Pred  Season  TeamOneID  TeamTwoID  TeamOne_Seed  TeamTwo_Seed  \
# 0  0.448682  2019.0     1101.0     1113.0          15.0          11.0
# 1  0.226137  2019.0     1101.0     1120.0          15.0           5.0
# 2  0.366104  2019.0     1101.0     1124.0          15.0           9.0
# 3  0.280782  2019.0     1101.0     1125.0          15.0          11.0
# 4  0.631411  2019.0     1101.0     1133.0          15.0          15.0
# 5  0.205015  2019.0     1101.0     1138.0          15.0           6.0
# 6  0.284434  2019.0     1101.0     1153.0          15.0           7.0
# 7  0.450334  2019.0     1101.0     1159.0          15.0          15.0
# 8  0.108239  2019.0     1101.0     1181.0          15.0           1.0
# 9  0.539113  2019.0     1101.0     1192.0          15.0          16.0
#
#    TeamOne_Ast  TeamOne_Ast_opp  TeamOne_Blk  TeamOne_Blk_opp  TeamOne_DR  \
# 0     14.62069        11.103448     2.551724         2.965517   22.896552
# ...
